# %% [markdown]
# # Sentiment Analysis with NLP
#
# Objective:
# Perform sentiment analysis using TF-IDF Vectorization and Logistic Regression.

# %% [markdown]
# # Sentiment Analysis using TF-IDF and Logistic Regression
#
# Objective:
# Analyze customer reviews and classify them as Positive or Negative.

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %% [markdown]
# ## Step 2: Create Dataset

# %%
data = {
    'review': [
        'This product is amazing',
        'I love this item',
        'Very good quality',
        'Excellent service',
        'I am happy with this purchase',
        'Fantastic experience',
        'Very satisfied',
        'Superb product',
        'Highly recommended',
        'Great packaging',

        'Very bad product',
        'Terrible experience',
        'Waste of money',
        'Poor quality',
        'I hate this item',
        'Worst purchase ever',
        'Very disappointed',
        'Not worth buying',
        'Bad service',
        'Completely useless'
    ],

    'sentiment': [
        'Positive','Positive','Positive','Positive','Positive',
        'Positive','Positive','Positive','Positive','Positive',

        'Negative','Negative','Negative','Negative','Negative',
        'Negative','Negative','Negative','Negative','Negative'
    ]
}

df = pd.DataFrame(data)

df
# Out:
#                            review sentiment
# 0         This product is amazing  Positive
# 1                I love this item  Positive
# 2               Very good quality  Positive
# 3               Excellent service  Positive
# 4   I am happy with this purchase  Positive
# 5            Fantastic experience  Positive
# 6                  Very satisfied  Positive
# 7                  Superb product  Positive
# 8              Highly recommended  Positive
# 9                 Great packaging  Positive
# 10               Very bad product  Negative
# 11            Terrible experience  Negative
# 12                 Waste of money  Negative
# 13                   Poor quality  Negative
# 14               I hate this item  Negative
# 15            Worst purchase ever  Negative
# 16              Very disappointed  Negative
# 17               Not worth buying  Negative
# 18                    Bad service  Negative
# 19             Completely useless  Negative

# %% [markdown]
# ## Step 1: Convert text data into numerical form using TF-IDF

# %%
vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(df['review'])

y = df['sentiment']

print("TF-IDF conversion completed")
# Out:
# TF-IDF conversion completed

# %% [markdown]
# ## Step 4: Split Dataset into Training and Testing Data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=1,
    stratify=y
)

print("Training data:", X_train.shape[0])

print("Testing data:", X_test.shape[0])
# Out:
# Training data: 14
# Testing data: 6

# %% [markdown]
# ## Step 2: Train the Logistic Regression model

# %%
model = LogisticRegression()

model.fit(X_train, y_train)

print("Model trained successfully")
# Out:
# Model trained successfully

# %%
predictions = model.predict(X_test)

accuracy = accuracy_score(
    y_test,
    predictions
)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.0

# %%
test_reviews = [
    "I really love this product",
    "This is a terrible item"
]

test_vector = vectorizer.transform(test_reviews)

results = model.predict(test_vector)

for review, result in zip(test_reviews, results):
    print(review, "->", result)
# Out:
# I really love this product -> Positive
# This is a terrible item -> Negative

# %%
test_reviews = [
    "I really love this product",
    "This is a terrible item",
    "Excellent quality",
    "Waste of money"
]

test_vector = vectorizer.transform(test_reviews)

results = model.predict(test_vector)

for review, result in zip(test_reviews, results):
    print(f"{review} -> {result}")
# Out:
# I really love this product -> Positive
# This is a terrible item -> Negative
# Excellent quality -> Positive
# Waste of money -> Negative

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predictions)

print(cm)
# Out:
# [[0 3]
#  [3 0]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       3.0
#     Positive       0.00      0.00      0.00       3.0
#
#     accuracy                           0.00       6.0
#    macro avg       0.00      0.00      0.00       6.0
# weighted avg       0.00      0.00      0.00       6.0

# %%
print(df.shape)

print(df['sentiment'].value_counts())
# Out:
# (20, 2)
# sentiment
# Positive    10
# Negative    10
# Name: count, dtype: int64

# %%
print("Notebook is working")
# Out:
# Notebook is working

# %%
print(df.head())
# Out:
#                           review sentiment
# 0        This product is amazing  Positive
# 1               I love this item  Positive
# 2              Very good quality  Positive
# 3              Excellent service  Positive
# 4  I am happy with this purchase  Positive
